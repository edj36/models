# %% [markdown]
# Predict Notes
#
# Moneypuck datasource: http://moneypuck.com/data.htm

# %%
import pandas as pd

# %%
vgk_file = 'http://moneypuck.com/moneypuck/playerData/careers/gameByGame/regular/teams/VGK.csv'

# %%
vgk_df = pd.read_csv(vgk_file)

# %%
vgk_df
# Out:
#      team  season name      gameId playerTeam opposingTeam home_or_away  \
# 0     VGK    2017  VGK  2017020015        VGK          DAL         AWAY
# 1     VGK    2017  VGK  2017020015        VGK          DAL         AWAY
# 2     VGK    2017  VGK  2017020015        VGK          DAL         AWAY
# 3     VGK    2017  VGK  2017020015        VGK          DAL         AWAY
# 4     VGK    2017  VGK  2017020015        VGK          DAL         AWAY
# ...   ...     ...  ...         ...        ...          ...          ...
# 1160  VGK    2019  VGK  2019021045        VGK          WPG         AWAY
# 1161  VGK    2019  VGK  2019021045        VGK          WPG         AWAY
# 1162  VGK    2019  VGK  2019021045        VGK          WPG         AWAY
# 1163  VGK    2019  VGK  2019021045        VGK          WPG         AWAY
# 1164  VGK    2019  VGK  2019021045        VGK          WPG         AWAY
#
#       gameDate    position situation  ...  scoreAdjustedShotsAttemptsAgainst  \
# ...

# %%
# bottom up
# given two teams
# get expected roster
# get xG for each player in expected roster
# sum them for each team, predict winner with expected goals

# %%
# other factors
# rest
# historical performance vs team
# line matchups
# goalies xG?
# top down prediction, then weighted average for each
# % chance instead of boolean outcome
# replicate moneypuck
# natural stat trick
# get historical team level data from ^^, use that to get historical xG for team, etc
# regression on that for simple prediction
# take predictions from existing sites and assign each a weighting, get combined prediction from that

# %% [markdown]
# Links:
#
# - http://www.corsica.hockey/blog/2016/03/03/shot-quality-and-expected-goals-part-i/
# - https://hockey-graphs.com/2015/10/01/expected-goals-are-a-better-predictor-of-future-scoring-than-corsi-goals/
